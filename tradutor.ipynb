# %%
# !pip install requests beautifulsoup4 openai langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.1/122.1 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.6/561.6 kB 14.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.9
#     Uninstalling langchain-core-1.4.9:
#       Successfully uninstalled langchain-core-1.4.9
# ...

# %%
import requests
from bs4 import BeautifulSoup

def extract_text_from_url(url):
    response = requests.get(url)

    if response.status_code == 200:
      soup = BeautifulSoup(response.text, 'html.parser')
      for script_or_style in soup(["script", "style"]):
        script_or_style.decompose()
      text = soup.get_text(separator = ' ')
      #limpar texto
      lines = (line.strip() for line in text.splitlines())
      chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
      texto_limpo = '\n'.join(chunk for chunk in chunks if chunk)
      return texto_limpo
    else:
      print(f"Failed to fetch URL. Status code: {response.status_code}")
      return None

    soup = BeautifulSoup(response.text, 'html.parser')
    text = soup.get_text()
    return text

extract_text_from_url('https://dev.to/kenakamu/azure-open-ai-in-vnet-3alo')
# Out:
# "Azure Open AI in VNet - DEV Community\nSkip to content\nNavigation menu\nSearch\nPowered by Algolia\nSearch\nLog in\nCreate account\nDEV Community\nClose\nAdd reaction\nLike\nUnicorn\nExploding Head\nRaised Hands\nFire\nJump to Comments\nSave\nBoost\nMore...\nCopy link\nCopy link\nCopied to Clipboard\nShare to X\nShare to LinkedIn\nShare to Facebook\nShare to Mastodon\nReport Abuse\nKenichiro Nakamura\nPosted on\nOct 12, 2023\nAzure Open AI in VNet\n# azure\n# openai\n# security\nGPT models are hosted in multiple service vendor at the moment, and Microsoft Azure is one of them.\nEven though the models themselves are the same, there are many differences including:\ncost\nfunctionalities\ntype of models and versions\ngeo location\nsecurity\nsupport\netc.\nOne of the most important aspects when we use it in an Enterprise Environment is, of course, security.\nBy using Azure network security features with Azure Open AI, customers can consume the Open AI service from and within the VNet, 
# ...

# %%
from langchain_openai import ChatOpenAI

client = ChatOpenAI(
    base_url = "https://kauanpains-8103-resource.services.ai.azure.com/openai/v1",
    api_key = "SUA_CHAVE_AQUI",
    model = "gpt-5-mini",
    max_retries = 0
)


def translate_article(text, lang):
  messages = [
      ("system" , "Você atua como tradutor de textos"),
      ("user", f"Traduza o {text} para o idioma {lang} e responda em markdown")

  ]

  response = client.invoke(messages)
  print(response.content)
  return response.content

translate_article("The bicep file will deploy following Azure Resources.", "portugues")
# Out:
# O arquivo Bicep implantará os seguintes recursos do Azure.
# 'O arquivo Bicep implantará os seguintes recursos do Azure.'

# %%
url = "https://dev.to/kenakamu/azure-open-ai-in-vnet-3alo"
text = extract_text_from_url(url)
article = translate_article(text, "pt-br")

print(article)
# Out:
# # Azure Open AI in VNet
#
# Ir para o conteúdo
#
# Menu de navegação
# Pesquisa
# Powered by Algolia
# Pesquisar
# Entrar
# Criar conta
#
# DEV Community
#
# Fechar
#
# Reagir
# Curtir
# Unicórnio
# Cabeça Explodindo
# Mãos Levantadas
# Fogo
#
# Ir para comentários
# Salvar
# Impulsionar
# Mais...
# Copiar link
# Copiar link
# Copiado para a área de transferência
# Compartilhar no X
# Compartilhar no LinkedIn
# Compartilhar no Facebook
# Compartilhar no Mastodon
# Denunciar abuso
#
# Kenichiro Nakamura
# Publicado em 12 de out. de 2023
#
# Azure Open AI em VNet
# # azure
# # openai
# # segurança
#
# Modelos GPT estão hospedados por vários provedores de serviço no momento, e a Microsoft Azure é um deles.
# Mesmo que os próprios modelos sejam os mesmos, existem muitas diferenças, incluindo:
# - custo
# - funcionalidades
# - tipos de modelos e versões
# - localização geográfica
# - segurança
# - suporte
# - etc.
#
# ...
